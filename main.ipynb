# %%
import datetime
import gzip
# mecab-python3 installed from pip
import MeCab
import polars as pl
import urllib.request

# %%
# なろうAPIを叩く
# APIDOC: https://dev.syosetu.com/man/api/
url = "https://api.syosetu.com/novelapi/api/?biggenre=2&out=json"

query_params = {
    # 大ジャンル指定
    "biggenre": 2,
    # gzipレベル
    "gzip": 5,
    # 出力形式
    "out": "json",
    # 過去7日間の更新のもののみ
    "lastupdate": "thisweek",
    # ピックアップ作品のみ
    "ispickup": 1,
    # R15作品は除外
    "notr15": 1,
    # 評価が高い順
    "order": "hyoka",
    # 100件
    "lim": 100
}

req = urllib.request.Request(
    "{}?{}".format(
        url,
        urllib.parse.urlencode(query_params),
    )
)

# %%
# API Request
with urllib.request.urlopen(req) as res:
    decoded_res = gzip.GzipFile(fileobj=res)
    body = decoded_res.read()

# %%
# save json to body_responces
body_json = body.decode("utf-8")
now = datetime.datetime.now()

path = "body_responses/body_json_{}.json".format(now.strftime("%Y%m%d%H%M%S"))
with open(path, mode="w") as file:
    file.write(body_json)

# %%
# Read JSON as polar dataframe
# 1行目は件数なので除外
df_body = pl.read_json(path).with_row_count("row_number").filter(pl.col("row_number") > 1).sort("global_point", reverse=True)
df_body.head()
# Out:
# shape: (5, 41)
# ┌──────────┬──────────┬────────────┬─────────┬─────┬───────────┬───────────┬────────────┬──────────┐
# │ row_numb ┆ allcount ┆ title      ┆ ncode   ┆ ... ┆ sasie_cnt ┆ kaiwaritu ┆ novelupdat ┆ updated_ │
# │ er       ┆ ---      ┆ ---        ┆ ---     ┆     ┆ ---       ┆ ---       ┆ ed_at      ┆ at       │
# │ ---      ┆ i64      ┆ str        ┆ str     ┆     ┆ i64       ┆ i64       ┆ ---        ┆ ---      │
# │ u32      ┆          ┆            ┆         ┆     ┆           ┆           ┆ str        ┆ str      │
# ╞══════════╪══════════╪════════════╪═════════╪═════╪═══════════╪═══════════╪════════════╪══════════╡
# │ 2        ┆ null     ┆ エノク第二 ┆ N2542DR ┆ ... ┆ 3         ┆ 42        ┆ 2023-02-17 ┆ 2023-02- │
# │          ┆          ┆ 部隊の遠征 ┆         ┆     ┆           ┆           ┆ 11:42:48   ┆ 17       │
# │          ┆          ┆ ごはん     ┆         ┆     ┆           ┆           ┆            ┆ 20:34:14 │
# │ 3        ┆ null     ┆ 【連載版】 ┆ N7146EG ┆ ... ┆ 0         ┆ 31        ┆ 2023-02-14 ┆ 2023-02- │
# │          ┆          ┆ 双子の姉が ┆         ┆     ┆           ┆           ┆ 20:42:40   ┆ 17       │
# │          ┆          ┆ 神子として ┆         ┆     ┆           ┆           ┆            ┆ 18:27:53 │
# │          ┆          ┆ 引き取られ ┆         ┆     ┆           ┆           ┆            ┆          │
# │          ┆          ┆ て、私は捨 ┆         ┆     ┆           ┆           ┆            ┆          │
# │          ┆          ┆ てられたけ ┆         ┆     ┆           ┆           ┆            ┆          │
# │          ┆          ┆ ど多...    ┆         ┆     ┆           ┆           ┆            ┆          │
# │ 4        ┆ null     ┆ どうやら私 ┆ N3881DN ┆ ... ┆ 2         ┆ 46        ┆ 2023-02-16 ┆ 2023-02- │
# │          ┆          ┆ の身体は完 ┆         ┆     ┆           ┆           ┆ 00:21:43   ┆ 17       │
# │          ┆          ┆ 全無敵のよ ┆         ┆     ┆           ┆           ┆            ┆ 21:04:13 │
# │          ┆          ┆ うですね   ┆         ┆     ┆           ┆           ┆            ┆          │
# │ 5        ┆ null     ┆ 大賢者の愛 ┆ N2159DD ┆ ... ┆ 0         ┆ 40        ┆ 2023-02-13 ┆ 2023-02- │
# │          ┆          ┆ 弟子　〜防 ┆         ┆     ┆           ┆           ┆ 12:00:16   ┆ 17       │
# │          ┆          ┆ 御魔法のス ┆         ┆     ┆           ┆           ┆            ┆ 20:29:11 │
# │          ┆          ┆ スメ〜     ┆         ┆     ┆           ┆           ┆            ┆          │
# │ 6        ┆ null     ┆ ロメリア戦 ┆ N3159FS ┆ ... ┆ 0         ┆ 34        ┆ 2023-02-17 ┆ 2023-02- │
# │          ┆          ┆ 記～魔王を ┆         ┆     ┆           ┆           ┆ 00:39:35   ┆ 17       │
# │          ┆          ┆ 倒した後も ┆         ┆     ┆           ┆           ┆            ┆ 20:54:54 │
# │          ┆          ┆ 人類やばそ ┆         ┆     ┆           ┆           ┆            ┆          │
# │          ┆          ┆ うだから軍 ┆         ┆     ┆           ┆           ┆            ┆          │
# │          ┆          ┆ 隊組織した ┆         ┆     ┆           ┆           ┆            ┆          │
# │          ┆          ┆ ～         ┆         ┆     ┆           ┆           ┆            ┆          │
# └──────────┴──────────┴────────────┴─────────┴─────┴───────────┴───────────┴────────────┴──────────┘

# %%
titles = df_body.select("title").get_column("title").to_list()
stories = df_body.select("story").get_column("story").to_list()

# %%
titles[0]
# Out:
# 'エノク第二部隊の遠征ごはん'

# %%
# titleを形態素解析する
tagger = MeCab.Tagger("-Owakati")
tagger2 = MeCab.Tagger("-Owakati")

titles_node = tagger.parseToNode("".join(titles))
stories_node = tagger2.parseToNode("".join(stories))

# %%
titles_node_values = []
stories_node_values = []

temp_t = titles_node
while temp_t:
    parsed_nodes = [temp_t.surface]
    parsed_nodes.extend(temp_t.feature.split(","))
    parsed_nodes.append(temp_t.posid)

    titles_node_values.append([
        parsed_nodes[0],
        parsed_nodes[1],
        parsed_nodes[2],
        parsed_nodes[3],
        parsed_nodes[4],
        parsed_nodes[5],
        parsed_nodes[6],
        parsed_nodes[7]
    ])

    temp_t = temp_t.next
    
temp_t = stories_node
while temp_t:
    parsed_nodes = [temp_t.surface]
    parsed_nodes.extend(temp_t.feature.split(","))
    parsed_nodes.append(temp_t.posid)

    stories_node_values.append([
        parsed_nodes[0],
        parsed_nodes[1],
        parsed_nodes[2],
        parsed_nodes[3],
        parsed_nodes[4],
        parsed_nodes[5],
        parsed_nodes[6],
        parsed_nodes[7]
    ])

    temp_t = temp_t.next

# %%
titles_node_values[1]
# Out:
# ['エノク', '名詞', '普通名詞', '一般', '*', '*', '*', 1]

# %%
stories_node_values[1]
# Out:
# ['遠征', '名詞', '普通名詞', 'サ変可能', '*', '*', '*', 'エンセイ']

# %%
# create polars dataframe
data = titles_node_values
cols = ["surface", "品詞", "p", "a", "b", "c", "d", "e"]
df_nodes = pl.DataFrame(
    data,
    cols,
)

df_nodes.filter((pl.col("品詞") == "名詞") | (pl.col("品詞") == "形容詞")).groupby(["surface", "品詞"]).agg([
    pl.col("surface").count().alias("c")
]).sort("c", reverse=True)
# Out:
# shape: (398, 3)
# ┌─────────┬──────┬─────┐
# │ surface ┆ 品詞 ┆ c   │
# │ ---     ┆ ---  ┆ --- │
# │ str     ┆ str  ┆ u32 │
# ╞═════════╪══════╪═════╡
# │ 世界    ┆ 名詞 ┆ 43  │
# │ 転生    ┆ 名詞 ┆ 18  │
# │ 最強    ┆ 名詞 ┆ 11  │
# │ 魔法    ┆ 名詞 ┆ 11  │
# │ ...     ┆ ...  ┆ ... │
# │ 複数    ┆ 名詞 ┆ 1   │
# │ 後      ┆ 名詞 ┆ 1   │
# │ NPC     ┆ 名詞 ┆ 1   │
# │ 王国    ┆ 名詞 ┆ 1   │
# └─────────┴──────┴─────┘

# %%
# create polars dataframe
data = stories_node_values
cols = ["surface", "品詞", "p", "a", "b", "c", "d", "e"]
df_nodes = pl.DataFrame(
    data,
    cols,
)

df_nodes.filter((pl.col("品詞") == "名詞") | (pl.col("品詞") == "形容詞")).groupby(["surface", "品詞"]).agg([
    pl.col("surface").count().alias("c")
]).sort("c", reverse=True)
# Out:
# shape: (2189, 3)
# ┌─────────┬──────┬─────┐
# │ surface ┆ 品詞 ┆ c   │
# │ ---     ┆ ---  ┆ --- │
# │ str     ┆ str  ┆ u32 │
# ╞═════════╪══════╪═════╡
# │ 世界    ┆ 名詞 ┆ 161 │
# │ こと    ┆ 名詞 ┆ 69  │
# │ 転生    ┆ 名詞 ┆ 58  │
# │ 一      ┆ 名詞 ┆ 43  │
# │ ...     ┆ ...  ┆ ... │
# │ ピンク  ┆ 名詞 ┆ 1   │
# │ 魔弾    ┆ 名詞 ┆ 1   │
# │ 制作    ┆ 名詞 ┆ 1   │
# │ 超人    ┆ 名詞 ┆ 1   │
# └─────────┴──────┴─────┘
